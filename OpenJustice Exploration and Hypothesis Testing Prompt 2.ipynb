# %% [markdown]
# ![](https://github.com/sfbrigade/CA_DOJ_OpenJustice/blob/master/figure/ca_openjustice.png?raw=true)
#
# # Objective
# For the same criminal offense, are particular ethnic juvenile groups more likely to be treated with harsher consequences by law enforcement?

# %% [markdown]
# # Exploration
# ## Load CSV files from Azure into Dataframes

# %%
#Load DOJ arrests data from AzureML Datasets
from azureml import Workspace
ws = Workspace()
ds = ws.datasets['ca_doj_arrests_deidentified_2014_05-07-2016.csv']
frame = ds.to_dataframe()
# Out:
# /home/nbuser/env3/lib/python3.4/site-packages/pandas/io/parsers.py:1139: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
#View metadata
print(ds.name)
print(ds.data_type_id)
print(ds.size)
print(ds.created_date)
# Out:
# ca_doj_arrests_deidentified_2014_05-07-2016.csv
# GenericCSV
# 160596366
# 2016-06-05 19:19:55.812000

# %%
#Need to fix this code to bring in all files, not just 2014
import glob
test = glob.glob('ca_doj_arrests_deidentified_20[00-14]_05-07-2016.csv')
#dsarrests = ws.datasets['ca_doj_arrests_deidentified_*.csv']
#framearrests = dsarrests.to_dataframe()

# %%
test
# Out:
# []

# %%
#Load population data from AzureML Datasets in case it's needed later
dspop = ws.datasets['ca_county_population_by_race_gender_age_2005-2014_02-05-2016.csv']
framepop = dspop.to_dataframe()

# %%
#View metadata
print(dspop.name)
print(dspop.data_type_id)
print(dspop.size)
print(dspop.created_date)
# Out:
# ca_county_population_by_race_gender_age_2005-2014_02-05-2016.csv
# GenericCSV
# 6588820
# 2016-06-06 04:30:12.356000

# %%
framepop.dtypes
# Out:
# year           int64
# county        object
# race          object
# gender        object
# age_group     object
# population     int64
# dtype: object

# %%
#Load contextual data from AzureML Datasets in case it's needed later
dscontex = ws.datasets['ca_county_agency_contextual_indicators_2009-2014_05-03-2016.csv']
framecontex = dscontex.to_dataframe()

# %%
#View metadata
print(dscontex.name)
print(dscontex.data_type_id)
print(dscontex.size)
print(dscontex.created_date)
# Out:
# ca_county_agency_contextual_indicators_2009-2014_05-03-2016.csv
# GenericCSV
# 278930
# 2016-07-19 14:52:23.872000

# %%
framecontex.dtypes
# Out:
# year                       int64
# county                    object
# agency_name               object
# agency_code               object
# less_than_high_school    float64
# high_school_or_higher    float64
# bachelors_or_higher      float64
# per_capita_income        float64
# median_income            float64
# poverty_rate             float64
# employment_rate          float64
# unemployment_rate        float64
# dtype: object

# %% [markdown]
# ## Assess if seasonality should be explored further (all ages)

# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
#Histogram showing arrests by month of year
frame.arrest_month.hist(grid=False, bins=12)

# %%
#Check for seasonality - histogram showing arrest by day of month suggests potential seasonality for last day of month
frame.arrest_day.hist(grid=False, bins=30)

# %%
frameage = frame.loc[:,['age_group']].groupby('age_group').size().order(ascending=False)

# %%
frameage
# Out:
# age_group
# adult        1126022
# juvenile       86823
# dtype: int64

# %% [markdown]
# ## Assess if seasonality should be explored further (Juveniles only)

# %%
#Select juvenile arrests data only
framejuv = frame.loc[frame['age_group'] == 'juvenile']

# %%
framejuv.dtypes
# Out:
# county                      object
# agency_name                 object
# agency_code                 object
# arrest_year                  int64
# arrest_month                 int64
# arrest_day                   int64
# race_or_ethnicity           object
# gender                      object
# age_group                   object
# summary_offense_level       object
# offense_level               object
# bcs_offense_code             int64
# bcs_summary_offence_code     int64
# fbi_offense_code            object
# status_type                 object
# disposition                 object
# dtype: object

# %%
#View juvenile arrests data
framejuv
# Out:
#           county                       agency_name agency_code  arrest_year  \
# 437      Alameda  Alameda Co. Sheriff's Department         100         2014
# 438      Alameda  Alameda Co. Sheriff's Department         100         2014
# 439      Alameda  Alameda Co. Sheriff's Department         100         2014
# 440      Alameda  Alameda Co. Sheriff's Department         100         2014
# 441      Alameda  Alameda Co. Sheriff's Department         100         2014
# 442      Alameda  Alameda Co. Sheriff's Department         100         2014
# 443      Alameda  Alameda Co. Sheriff's Department         100         2014
# 444      Alameda  Alameda Co. Sheriff's Department         100         2014
# 445      Alameda  Alameda Co. Sheriff's Department         100         2014
# 446      Alameda  Alameda Co. Sheriff's Department         100         2014
# 447      Alameda  Alameda Co. Sheriff's Department         100         2014
# 448      Alameda  Alameda Co. Sheriff's Department         100         2014
# 449      Alameda  Alameda Co. Sheriff's Department         100         2014
# 450      Alameda  Alameda Co. Sheriff's Department         100         2014
# 451      Alameda  Alameda Co. Sheriff's Department         100         2014
# 452      Alameda  Alameda Co. Sheriff's Department         100         2014
# 453      Alameda  Alameda Co. Sheriff's Department         100         2014
# 454      Alameda  Alameda Co. Sheriff's Department         100         2014
# 455      Alameda  Alameda Co. Sheriff's Department         100         2014
# 456      Alameda  Alameda Co. Sheriff's Department         100         2014
# 457      Alameda  Alameda Co. Sheriff's Department         100         2014
# 467      Alameda  Alameda Co. Sheriff's Department         100         2014
# 884      Alameda  Alameda Co. Sheriff's Department         100         2014
# 885      Alameda  Alameda Co. Sheriff's Department         100         2014
# 886      Alameda  Alameda Co. Sheriff's Department         100         2014
# 887      Alameda  Alameda Co. Sheriff's Department         100         2014
# 888      Alameda  Alameda Co. Sheriff's Department         100         2014
# 889      Alameda  Alameda Co. Sheriff's Department         100         2014
# 890      Alameda  Alameda Co. Sheriff's Department         100         2014
# 891      Alameda  Alameda Co. Sheriff's Department         100         2014
# ...          ...                               ...         ...          ...
# 1212365     Yuba                        Marysville        5801         2014
# 1212366     Yuba                        Marysville        5801         2014
# 1212367     Yuba                        Marysville        5801         2014
# 1212368     Yuba                        Marysville        5801         2014
# 1212369     Yuba                        Marysville        5801         2014
# 1212441     Yuba                        Marysville        5801         2014
# 1212442     Yuba                        Marysville        5801         2014
# 1212443     Yuba                        Marysville        5801         2014
# 1212444     Yuba                        Marysville        5801         2014
# 1212500     Yuba                        Marysville        5801         2014
# 1212501     Yuba                        Marysville        5801         2014
# 1212502     Yuba                        Marysville        5801         2014
# 1212503     Yuba                        Marysville        5801         2014
# 1212513     Yuba                         Wheatland        5802         2014
# 1212520     Yuba                         Wheatland        5802         2014
# 1212521     Yuba                         Wheatland        5802         2014
# 1212522     Yuba                         Wheatland        5802         2014
# 1212531     Yuba                         Wheatland        5802         2014
# 1212534     Yuba                         Wheatland        5802         2014
# 1212538     Yuba                         Wheatland        5802         2014
# 1212559     Yuba                         Wheatland        5802         2014
# 1212562     Yuba                         Wheatland        5802         2014
# 1212563     Yuba                         Wheatland        5802         2014
# 1212570     Yuba                         Wheatland        5802         2014
# 1212571     Yuba                         Wheatland        5802         2014
# 1212574     Yuba                         Wheatland        5802         2014
# 1212578     Yuba                         Wheatland        5802         2014
# 1212579     Yuba                         Wheatland        5802         2014
# 1212580     Yuba                         Wheatland        5802         2014
# 1212585     Yuba                         Wheatland        5802         2014
#
#          arrest_month  arrest_day                  race_or_ethnicity  gender  \
# 437                 1           7                              Black  female
# 438                 1           9                           Hispanic    male
# 439                 1           9                              Black    male
# 440                 1          10                              Black    male
# 441                 1          13                           Hispanic    male
# 442                 1          14                              Black  female
# 443                 1          14                           Hispanic    male
# 444                 1          15                           Hispanic  female
# 445                 1          16                           Hispanic    male
# 446                 1          18                              Black  female
# 447                 1          18                           Hispanic  female
# 448                 1          18                              Black  female
# 449                 1          23                              Black    male
# 450                 1          23                              Black    male
# 451                 1          23                           Hispanic  female
# 452                 1          23                           Hispanic    male
# 453                 1          25                           Hispanic    male
# 454                 1          28                           Hispanic    male
# 455                 1          29                           Hispanic    male
# 456                 1          29                           Hispanic    male
# 457                 1          30                           Hispanic    male
# 467                 1          19                              Black  female
# 884                 2           4                              Black    male
# 885                 2           5                              White  female
# 886                 2           5                           Hispanic    male
# 887                 2           5                           Hispanic    male
# 888                 2           6             Asian/Pacific Islander    male
# 889                 2           7                              White  female
# 890                 2          12                           Hispanic    male
# 891                 2          12                              White    male
# ...               ...         ...                                ...     ...
# 1212365            10          14  suppressed_due_to_privacy_concern    male
# 1212366            10          21  suppressed_due_to_privacy_concern    male
# 1212367            10          21  suppressed_due_to_privacy_concern    male
# 1212368            10          21  suppressed_due_to_privacy_concern  female
# 1212369            10          21  suppressed_due_to_privacy_concern    male
# 1212441            11           4  suppressed_due_to_privacy_concern  female
# 1212442            11           4  suppressed_due_to_privacy_concern  female
# 1212443            11           7  suppressed_due_to_privacy_concern    male
# 1212444            11          24  suppressed_due_to_privacy_concern    male
# 1212500            12          18  suppressed_due_to_privacy_concern    male
# 1212501            12          18  suppressed_due_to_privacy_concern    male
# 1212502            12          18  suppressed_due_to_privacy_concern    male
# 1212503            12          18  suppressed_due_to_privacy_concern    male
# 1212513             2          26  suppressed_due_to_privacy_concern    male
# 1212520             4           3  suppressed_due_to_privacy_concern    male
# 1212521             4           3  suppressed_due_to_privacy_concern    male
# 1212522             4           4  suppressed_due_to_privacy_concern  female
# 1212531             6           1  suppressed_due_to_privacy_concern    male
# 1212534             6          11  suppressed_due_to_privacy_concern    male
# 1212538             6          24  suppressed_due_to_privacy_concern  female
# 1212559             8          13  suppressed_due_to_privacy_concern  female
# 1212562             9           8  suppressed_due_to_privacy_concern    male
# 1212563             9           9  suppressed_due_to_privacy_concern    male
# 1212570            10          22  suppressed_due_to_privacy_concern    male
# 1212571            10          24  suppressed_due_to_privacy_concern  female
# 1212574            10          27  suppressed_due_to_privacy_concern    male
# 1212578            12           2  suppressed_due_to_privacy_concern  female
# 1212579            12           4  suppressed_due_to_privacy_concern    male
# 1212580            12           4  suppressed_due_to_privacy_concern  female
# 1212585            12          22  suppressed_due_to_privacy_concern    male
#
#         age_group summary_offense_level   offense_level  bcs_offense_code  \
# 437      juvenile              juvenile          felony               844
# 438      juvenile              juvenile     misdemeanor               397
# 439      juvenile              juvenile          felony               345
# 440      juvenile              juvenile     misdemeanor               397
# 441      juvenile              juvenile          felony               810
# 442      juvenile              juvenile     misdemeanor               398
# 443      juvenile              juvenile     misdemeanor                98
# 444      juvenile              juvenile          felony               345
# 445      juvenile              juvenile          felony               320
# 446      juvenile              juvenile          felony               200
# 447      juvenile              juvenile          felony               200
# 448      juvenile              juvenile          felony               200
# 449      juvenile              juvenile     misdemeanor               787
# 450      juvenile              juvenile     misdemeanor               787
# 451      juvenile              juvenile     misdemeanor               787
# 452      juvenile              juvenile     misdemeanor               816
# 453      juvenile              juvenile     misdemeanor               346
# 454      juvenile              juvenile     misdemeanor               787
# 455      juvenile              juvenile          felony               570
# 456      juvenile              juvenile          felony                64
# 457      juvenile              juvenile     misdemeanor               397
# 467      juvenile              juvenile  status offense                 4
# 884      juvenile              juvenile     misdemeanor               396
# 885      juvenile              juvenile          felony               530
# 886      juvenile              juvenile          felony               530
# 887      juvenile              juvenile     misdemeanor               516
# 888      juvenile              juvenile     misdemeanor               397
# 889      juvenile              juvenile     misdemeanor               516
# 890      juvenile              juvenile     misdemeanor                68
# 891      juvenile              juvenile     misdemeanor                66
# ...           ...                   ...             ...               ...
# 1212365  juvenile              juvenile     misdemeanor                49
# 1212366  juvenile              juvenile     misdemeanor                49
# 1212367  juvenile              juvenile     misdemeanor                49
# 1212368  juvenile              juvenile     misdemeanor                96
# 1212369  juvenile              juvenile     misdemeanor                96
# 1212441  juvenile              juvenile     misdemeanor               816
# 1212442  juvenile              juvenile     misdemeanor               816
# 1212443  juvenile              juvenile     misdemeanor               816
# 1212444  juvenile              juvenile     misdemeanor               856
# 1212500  juvenile              juvenile          felony               345
# 1212501  juvenile              juvenile     misdemeanor               346
# 1212502  juvenile              juvenile     misdemeanor               849
# 1212503  juvenile              juvenile          felony               400
# 1212513  juvenile              juvenile     misdemeanor               399
# 1212520  juvenile              juvenile          felony               342
# 1212521  juvenile              juvenile     misdemeanor               846
# 1212522  juvenile              juvenile     misdemeanor               397
# 1212531  juvenile              juvenile          felony               570
# 1212534  juvenile              juvenile     misdemeanor               397
# 1212538  juvenile              juvenile          felony               570
# 1212559  juvenile              juvenile     misdemeanor                46
# 1212562  juvenile              juvenile     misdemeanor               396
# 1212563  juvenile              juvenile     misdemeanor                68
# 1212570  juvenile              juvenile     misdemeanor                96
# 1212571  juvenile              juvenile          felony               342
# 1212574  juvenile              juvenile     misdemeanor                89
# 1212578  juvenile              juvenile     misdemeanor               516
# 1212579  juvenile              juvenile     misdemeanor                77
# 1212580  juvenile              juvenile     misdemeanor               816
# 1212585  juvenile              juvenile     misdemeanor               856
#
#          bcs_summary_offence_code fbi_offense_code status_type  \
# 437                            19               15       cited
# 438                            30               08      booked
# 439                             6               04       cited
# 440                            30               08      booked
# 441                            13              18F       cited
# 442                            30               08       other
# 443                            59               26      booked
# 444                             6               04       cited
# 445                             6               04       other
# 446                             5               03      booked
# 447                             5               03      booked
# 448                             5               03      booked
# 449                            39               26       other
# 450                            39               26       other
# 451                            39               26       other
# 452                            34              18F       cited
# 453                            30               08       cited
# 454                            39               26       other
# 455                            10               07      booked
# 456                            25               14       cited
# 457                            30               08       other
# 467                            72               26       other
# 884                            30               08       cited
# 885                             9               13       cited
# 886                             9               13       cited
# 887                            31               06       cited
# 888                            30               08       cited
# 889                            31               06       cited
# 890                            49               26      booked
# 891                            47               14       cited
# ...                           ...              ...         ...
# 1212365                        60               26       cited
# 1212366                        60               26      booked
# 1212367                        60               26      booked
# 1212368                        60               26      booked
# 1212369                        60               26      booked
# 1212441                        34              18F       cited
# 1212442                        34              18F       cited
# 1212443                        34              18F       cited
# 1212444                        51               21      booked
# 1212500                         6               04      booked
# 1212501                        30               08      booked
# 1212502                        50               15      booked
# 1212503                         8               05      booked
# 1212513                        30               08      booked
# 1212520                         6               04       other
# 1212521                        50               15       other
# 1212522                        30               08       other
# 1212531                        10               07      booked
# 1212534                        30               08       other
# 1212538                        10               07      booked
# 1212559                        43               23       cited
# 1212562                        30               08       other
# 1212563                        49               26       cited
# 1212570                        60               26       cited
# 1212571                         6               04       other
# 1212574                        53              NaN       cited
# 1212578                        31               06      booked
# 1212579                        44               22       cited
# 1212580                        34              18F      booked
# 1212585                        51               21       cited
#
#                                        disposition
# 437      referred to juvenile probation department
# 438      referred to juvenile probation department
# 439                      handled within department
# 440      referred to juvenile probation department
# 441                      handled within department
# 442      referred to juvenile probation department
# 443      referred to juvenile probation department
# 444      referred to juvenile probation department
# 445      referred to juvenile probation department
# 446      referred to juvenile probation department
# 447      referred to juvenile probation department
# 448      referred to juvenile probation department
# 449      referred to juvenile probation department
# 450      referred to juvenile probation department
# 451      referred to juvenile probation department
# 452      referred to juvenile probation department
# 453      referred to juvenile probation department
# 454      referred to juvenile probation department
# 455      referred to juvenile probation department
# 456                      handled within department
# 457      referred to juvenile probation department
# 467                      handled within department
# 884      referred to juvenile probation department
# 885      referred to juvenile probation department
# 886      referred to juvenile probation department
# 887      referred to juvenile probation department
# 888      referred to juvenile probation department
# 889      referred to juvenile probation department
# 890      referred to juvenile probation department
# 891      referred to juvenile probation department
# ...                                            ...
# 1212365  referred to juvenile probation department
# 1212366  referred to juvenile probation department
# 1212367  referred to juvenile probation department
# 1212368  referred to juvenile probation department
# 1212369  referred to juvenile probation department
# 1212441                  handled within department
# 1212442  referred to juvenile probation department
# 1212443  referred to juvenile probation department
# 1212444  referred to juvenile probation department
# 1212500  referred to juvenile probation department
# 1212501  referred to juvenile probation department
# 1212502  referred to juvenile probation department
# 1212503  referred to juvenile probation department
# 1212513  referred to juvenile probation department
# 1212520  referred to juvenile probation department
# 1212521  referred to juvenile probation department
# 1212522  referred to juvenile probation department
# 1212531  referred to juvenile probation department
# 1212534  referred to juvenile probation department
# 1212538  referred to juvenile probation department
# 1212559  referred to juvenile probation department
# 1212562  referred to juvenile probation department
# 1212563  referred to juvenile probation department
# 1212570  referred to juvenile probation department
# 1212571  referred to juvenile probation department
# 1212574  referred to juvenile probation department
# 1212578  referred to juvenile probation department
# 1212579  referred to juvenile probation department
# 1212580  referred to juvenile probation department
# 1212585  referred to juvenile probation department
#
# [86823 rows x 16 columns]

# %%
#Juvenile arrest by month of year
framejuv.arrest_month.hist(grid=False, bins=12)

# %% [markdown]
# - Notice lower numbers of arrests in summer and winter months - potential relationship with being out of school

# %%
#Juvenile arrests by day of month
framejuv.arrest_day.hist(grid=False, bins=30)

# %% [markdown]
# - Notice peak on 31st of month - potential relationship with pay day, or bills due date.

# %%
#[2] returns the week day (1-7)
#todayWeekDay = date.today().isocalendar()[2]
#todayWeekDay

# %%
#Adding datetime and date formats
framejuv['datetime'] = pd.to_datetime(framejuv.arrest_year*10000 + framejuv.arrest_month*100 + framejuv.arrest_day, format="%Y%M%d")
framejuv['date'] = pd.DatetimeIndex(framejuv.datetime).normalize()

#Adding day of week
framejuv['week'] = pd.DatetimeIndex(framejuv['datetime']).dayofweek

# %%
#Juvenile arrests by day of week
framejuv.week.hist(grid=False, bins=7)

# %% [markdown]
# - Higher number of arrests mid-week Wednesday through Friday

# %%
#Potential to model seasonality here or include seasonality as contextual factor in later predictive model
import statsmodels.api as sm

# %% [markdown]
# ## High level groupings

# %%
#Group by offense level
framejuvbyoffense = framejuv.loc[:,['offense_level']].groupby('offense_level').size().order(ascending=False)

# %%
#View arrests by offense level
framejuvbyoffense
# Out:
# offense_level
# misdemeanor       48291
# felony            27651
# status offense    10881
# dtype: int64

# %%
#Group by gender
framejuvbygender = framejuv.loc[:,['gender']].groupby('gender').size().order(ascending=False)

# %%
#View arrests by gender
framejuvbygender
# Out:
# gender
# male      63221
# female    23602
# dtype: int64

# %%
#Group by race/ethnicity
framejuvbyrace = framejuv.loc[:,['race_or_ethnicity']].groupby('race_or_ethnicity').size().order(ascending=False)

# %%
#View arrests by race/ethnicity
framejuvbyrace
# Out:
# race_or_ethnicity
# Hispanic                             35449
# suppressed_due_to_privacy_concern    20596
# Black                                14392
# White                                12438
# Asian/Pacific Islander                1988
# Other                                 1960
# dtype: int64

# %%
#Identify BCS summary offense codes with highest frequency
framejuv.bcs_summary_offence_code.hist(grid=False, bins=66)

# %% [markdown]
# ## More granular groupings
# - Begin to explore differences in treatment of arrests for the same offense

# %%
#Select offense code 30
framejuv30 = framejuv.loc[framejuv['bcs_summary_offence_code'] == 30]

# %%
framejuvexplore0 = framejuv30.groupby(['race_or_ethnicity']).size()

# %%
#View race grouping for misdemeanor with BCS summary offense code 30
framejuvexplore0ind = framejuvexplore0.reset_index(name='count')

# %%
framejuvexplore0ind
# Out:
#                    race_or_ethnicity  count
# 0             Asian/Pacific Islander    239
# 1                              Black   2153
# 2                           Hispanic   3758
# 3                              Other    184
# 4                              White   1424
# 5  suppressed_due_to_privacy_concern   2585

# %%
framejuvexplore1 = framejuv30.groupby(['bcs_summary_offence_code', 'disposition', 'race_or_ethnicity']).size()

# %%
framejuvexplore1ind = framejuvexplore1.reset_index(name='count')

# %%
framejuvexplore1ind
# Out:
#     bcs_summary_offence_code                                disposition  \
# 0                         30                  handled within department
# 1                         30                  handled within department
# 2                         30                  handled within department
# 3                         30                  handled within department
# 4                         30                  handled within department
# 5                         30                  handled within department
# 6                         30  referred to juvenile probation department
# 7                         30  referred to juvenile probation department
# 8                         30  referred to juvenile probation department
# 9                         30  referred to juvenile probation department
# 10                        30  referred to juvenile probation department
# 11                        30  referred to juvenile probation department
# 12                        30                turned over to other agency
# 13                        30                turned over to other agency
# 14                        30                turned over to other agency
# 15                        30                turned over to other agency
# 16                        30                turned over to other agency
# 17                        30                turned over to other agency
#
#                     race_or_ethnicity  count
# 0              Asian/Pacific Islander     41
# 1                               Black    395
# 2                            Hispanic    540
# 3                               Other     29
# 4                               White    237
# 5   suppressed_due_to_privacy_concern    194
# 6              Asian/Pacific Islander    197
# 7                               Black   1729
# 8                            Hispanic   3170
# 9                               Other    152
# 10                              White   1177
# 11  suppressed_due_to_privacy_concern   2350
# 12             Asian/Pacific Islander      1
# 13                              Black     29
# 14                           Hispanic     48
# 15                              Other      3
# 16                              White     10
# 17  suppressed_due_to_privacy_concern     41

# %%
framejuvexplore2 = framejuv30.groupby(['bcs_summary_offence_code', 'status_type', 'race_or_ethnicity']).size()

# %%
framejuvexplore2ind = framejuvexplore2.reset_index(name='count')

# %%
framejuvexplore2ind
# Out:
#     bcs_summary_offence_code status_type                  race_or_ethnicity  \
# 0                         30      booked             Asian/Pacific Islander
# 1                         30      booked                              Black
# 2                         30      booked                           Hispanic
# 3                         30      booked                              Other
# 4                         30      booked                              White
# 5                         30      booked  suppressed_due_to_privacy_concern
# 6                         30       cited             Asian/Pacific Islander
# 7                         30       cited                              Black
# 8                         30       cited                           Hispanic
# 9                         30       cited                              Other
# 10                        30       cited                              White
# 11                        30       cited  suppressed_due_to_privacy_concern
# 12                        30       other             Asian/Pacific Islander
# 13                        30       other                              Black
# 14                        30       other                           Hispanic
# 15                        30       other                              Other
# 16                        30       other                              White
# 17                        30       other  suppressed_due_to_privacy_concern
#
#     count
# 0      83
# 1    1146
# 2    1973
# 3      82
# 4     682
# 5    1380
# 6     118
# 7     736
# 8    1161
# 9      74
# 10    505
# 11    944
# 12     38
# 13    271
# 14    624
# 15     28
# 16    237
# 17    261

# %% [markdown]
# An arrest means incarceration at the jail till your appearance date, or bail, or booked and released with a court date. A misdemeanor citation is a criminal ticket with a court date where you have not been booked at the county jail. Need to confirm below whether booked refers to heavier form of treatment than cited.

# %%
framejuvexplore3 = pd.merge(framejuvexplore0ind, framejuvexplore2ind, how='inner', on=['race_or_ethnicity', 'race_or_ethnicity'])

# %%
framejuvexplore3['rate'] = framejuvexplore3['count_y'] / framejuvexplore3['count_x']

# %%
framejuvexplore3
# Out:
#                     race_or_ethnicity  count_x  bcs_summary_offence_code  \
# 0              Asian/Pacific Islander      239                        30
# 1              Asian/Pacific Islander      239                        30
# 2              Asian/Pacific Islander      239                        30
# 3                               Black     2153                        30
# 4                               Black     2153                        30
# 5                               Black     2153                        30
# 6                            Hispanic     3758                        30
# 7                            Hispanic     3758                        30
# 8                            Hispanic     3758                        30
# 9                               Other      184                        30
# 10                              Other      184                        30
# 11                              Other      184                        30
# 12                              White     1424                        30
# 13                              White     1424                        30
# 14                              White     1424                        30
# 15  suppressed_due_to_privacy_concern     2585                        30
# 16  suppressed_due_to_privacy_concern     2585                        30
# 17  suppressed_due_to_privacy_concern     2585                        30
#
#    status_type  count_y      rate
# 0       booked       83  0.347280
# 1        cited      118  0.493724
# 2        other       38  0.158996
# 3       booked     1146  0.532281
# 4        cited      736  0.341849
# 5        other      271  0.125871
# 6       booked     1973  0.525013
# 7        cited     1161  0.308941
# 8        other      624  0.166046
# 9       booked       82  0.445652
# 10       cited       74  0.402174
# 11       other       28  0.152174
# 12      booked      682  0.478933
# 13       cited      505  0.354635
# 14       other      237  0.166433
# 15      booked     1380  0.533849
# 16       cited      944  0.365184
# 17       other      261  0.100967

# %%
framejuvexplore4 = framejuv30.groupby(['race_or_ethnicity', 'arrest_month']).size()

# %%
framejuvexplore4ind = framejuvexplore4.reset_index(name='count')

# %%
framejuvexplore5 = framejuv30.groupby(['bcs_summary_offence_code', 'status_type', 'race_or_ethnicity', 'arrest_month']).size()

# %%
framejuvexplore5ind = framejuvexplore5.reset_index(name='count')

# %%
framejuvexplore6 = pd.merge(framejuvexplore4ind, framejuvexplore5ind, how='inner', on=['race_or_ethnicity', 'arrest_month'])

# %%
framejuvexplore6['rate'] = framejuvexplore6['count_y'] / framejuvexplore6['count_x']

# %%
framejuvexplore6
# Out:
#                      race_or_ethnicity  arrest_month  count_x  \
# 0               Asian/Pacific Islander             1       24
# 1               Asian/Pacific Islander             1       24
# 2               Asian/Pacific Islander             1       24
# 3               Asian/Pacific Islander             2       31
# 4               Asian/Pacific Islander             2       31
# 5               Asian/Pacific Islander             2       31
# 6               Asian/Pacific Islander             3       24
# 7               Asian/Pacific Islander             3       24
# 8               Asian/Pacific Islander             3       24
# 9               Asian/Pacific Islander             4       28
# 10              Asian/Pacific Islander             4       28
# 11              Asian/Pacific Islander             4       28
# 12              Asian/Pacific Islander             5       20
# 13              Asian/Pacific Islander             5       20
# 14              Asian/Pacific Islander             5       20
# 15              Asian/Pacific Islander             6       12
# 16              Asian/Pacific Islander             6       12
# 17              Asian/Pacific Islander             6       12
# 18              Asian/Pacific Islander             7        8
# 19              Asian/Pacific Islander             7        8
# 20              Asian/Pacific Islander             7        8
# 21              Asian/Pacific Islander             8       10
# 22              Asian/Pacific Islander             8       10
# 23              Asian/Pacific Islander             8       10
# 24              Asian/Pacific Islander             9       20
# 25              Asian/Pacific Islander             9       20
# 26              Asian/Pacific Islander             9       20
# 27              Asian/Pacific Islander            10       28
# 28              Asian/Pacific Islander            10       28
# 29              Asian/Pacific Islander            10       28
# ..                                 ...           ...      ...
# 183  suppressed_due_to_privacy_concern             3      273
# 184  suppressed_due_to_privacy_concern             3      273
# 185  suppressed_due_to_privacy_concern             3      273
# 186  suppressed_due_to_privacy_concern             4      228
# 187  suppressed_due_to_privacy_concern             4      228
# 188  suppressed_due_to_privacy_concern             4      228
# 189  suppressed_due_to_privacy_concern             5      303
# 190  suppressed_due_to_privacy_concern             5      303
# 191  suppressed_due_to_privacy_concern             5      303
# 192  suppressed_due_to_privacy_concern             6      160
# 193  suppressed_due_to_privacy_concern             6      160
# 194  suppressed_due_to_privacy_concern             6      160
# 195  suppressed_due_to_privacy_concern             7      160
# 196  suppressed_due_to_privacy_concern             7      160
# 197  suppressed_due_to_privacy_concern             7      160
# 198  suppressed_due_to_privacy_concern             8      153
# 199  suppressed_due_to_privacy_concern             8      153
# 200  suppressed_due_to_privacy_concern             8      153
# 201  suppressed_due_to_privacy_concern             9      252
# 202  suppressed_due_to_privacy_concern             9      252
# 203  suppressed_due_to_privacy_concern             9      252
# 204  suppressed_due_to_privacy_concern            10      222
# 205  suppressed_due_to_privacy_concern            10      222
# 206  suppressed_due_to_privacy_concern            10      222
# 207  suppressed_due_to_privacy_concern            11      200
# 208  suppressed_due_to_privacy_concern            11      200
# 209  suppressed_due_to_privacy_concern            11      200
# 210  suppressed_due_to_privacy_concern            12      196
# 211  suppressed_due_to_privacy_concern            12      196
# 212  suppressed_due_to_privacy_concern            12      196
#
#      bcs_summary_offence_code status_type  count_y      rate
# 0                          30      booked       10  0.416667
# 1                          30       cited       11  0.458333
# 2                          30       other        3  0.125000
# 3                          30      booked       15  0.483871
# 4                          30       cited       12  0.387097
# 5                          30       other        4  0.129032
# 6                          30      booked       10  0.416667
# 7                          30       cited       12  0.500000
# 8                          30       other        2  0.083333
# 9                          30      booked       12  0.428571
# 10                         30       cited       13  0.464286
# 11                         30       other        3  0.107143
# 12                         30      booked        6  0.300000
# 13                         30       cited       11  0.550000
# 14                         30       other        3  0.150000
# 15                         30      booked        4  0.333333
# 16                         30       cited        5  0.416667
# 17                         30       other        3  0.250000
# 18                         30      booked        2  0.250000
# 19                         30       cited        3  0.375000
# 20                         30       other        3  0.375000
# 21                         30      booked        3  0.300000
# 22                         30       cited        5  0.500000
# 23                         30       other        2  0.200000
# 24                         30      booked        4  0.200000
# 25                         30       cited       14  0.700000
# 26                         30       other        2  0.100000
# 27                         30      booked        5  0.178571
# 28                         30       cited       19  0.678571
# 29                         30       other        4  0.142857
# ..                        ...         ...      ...       ...
# 183                        30      booked      154  0.564103
# 184                        30       cited       94  0.344322
# 185                        30       other       25  0.091575
# 186                        30      booked      123  0.539474
# 187                        30       cited       86  0.377193
# 188                        30       other       19  0.083333
# 189                        30      booked      166  0.547855
# 190                        30       cited      104  0.343234
# 191                        30       other       33  0.108911
# 192                        30      booked       87  0.543750
# 193                        30       cited       63  0.393750
# 194                        30       other       10  0.062500
# 195                        30      booked      100  0.625000
# 196                        30       cited       42  0.262500
# 197                        30       other       18  0.112500
# 198                        30      booked       81  0.529412
# 199                        30       cited       59  0.385621
# 200                        30       other       13  0.084967
# 201                        30      booked      116  0.460317
# 202                        30       cited      106  0.420635
# 203                        30       other       30  0.119048
# 204                        30      booked      112  0.504505
# 205                        30       cited       85  0.382883
# 206                        30       other       25  0.112613
# 207                        30      booked      108  0.540000
# 208                        30       cited       71  0.355000
# 209                        30       other       21  0.105000
# 210                        30      booked      100  0.510204
# 211                        30       cited       68  0.346939
# 212                        30       other       28  0.142857
#
# [213 rows x 7 columns]

# %%
framejuvexplore6asian = framejuvexplore6.loc[framejuvexplore6['race_or_ethnicity'] == 'Asian/Pacific Islander']
framejuvexplore6asianbooked = framejuvexplore6asian.loc[framejuvexplore6asian['status_type'] == 'booked']

# %%
framejuvexplore6asianbooked
# Out:
#          race_or_ethnicity  arrest_month  count_x  bcs_summary_offence_code  \
# 0   Asian/Pacific Islander             1       24                        30
# 3   Asian/Pacific Islander             2       31                        30
# 6   Asian/Pacific Islander             3       24                        30
# 9   Asian/Pacific Islander             4       28                        30
# 12  Asian/Pacific Islander             5       20                        30
# 15  Asian/Pacific Islander             6       12                        30
# 18  Asian/Pacific Islander             7        8                        30
# 21  Asian/Pacific Islander             8       10                        30
# 24  Asian/Pacific Islander             9       20                        30
# 27  Asian/Pacific Islander            10       28                        30
# 30  Asian/Pacific Islander            11       21                        30
# 33  Asian/Pacific Islander            12       13                        30
#
#    status_type  count_y      rate
# 0       booked       10  0.416667
# 3       booked       15  0.483871
# 6       booked       10  0.416667
# 9       booked       12  0.428571
# 12      booked        6  0.300000
# 15      booked        4  0.333333
# 18      booked        2  0.250000
# 21      booked        3  0.300000
# 24      booked        4  0.200000
# 27      booked        5  0.178571
# 30      booked        5  0.238095
# 33      booked        7  0.538462

# %%
framejuvexplore6asianbooked.rate.hist(grid=False)

# %%
framejuvexplore6black = framejuvexplore6.loc[framejuvexplore6['race_or_ethnicity'] == 'Black']
framejuvexplore6blackbooked = framejuvexplore6black.loc[framejuvexplore6black['status_type'] == 'booked']

# %%
framejuvexplore6blackbooked
# Out:
#    race_or_ethnicity  arrest_month  count_x  bcs_summary_offence_code  \
# 36             Black             1      170                        30
# 39             Black             2      220                        30
# 42             Black             3      219                        30
# 45             Black             4      199                        30
# 48             Black             5      257                        30
# 51             Black             6      143                        30
# 54             Black             7      112                        30
# 57             Black             8      109                        30
# 60             Black             9      192                        30
# 63             Black            10      209                        30
# 66             Black            11      167                        30
# 69             Black            12      156                        30
#
#    status_type  count_y      rate
# 36      booked       78  0.458824
# 39      booked      107  0.486364
# 42      booked      117  0.534247
# 45      booked      112  0.562814
# 48      booked      132  0.513619
# 51      booked       72  0.503497
# 54      booked       74  0.660714
# 57      booked       63  0.577982
# 60      booked       97  0.505208
# 63      booked      114  0.545455
# 66      booked       88  0.526946
# 69      booked       92  0.589744

# %%
framejuvexplore6hispanic = framejuvexplore6.loc[framejuvexplore6['race_or_ethnicity'] == 'Hispanic']
framejuvexplore6hispanicbooked = framejuvexplore6hispanic.loc[framejuvexplore6hispanic['status_type'] == 'booked']

# %%
framejuvexplore6hispanicbooked
# Out:
#     race_or_ethnicity  arrest_month  count_x  bcs_summary_offence_code  \
# 72           Hispanic             1      290                        30
# 75           Hispanic             2      306                        30
# 78           Hispanic             3      400                        30
# 81           Hispanic             4      339                        30
# 84           Hispanic             5      411                        30
# 87           Hispanic             6      248                        30
# 90           Hispanic             7      188                        30
# 93           Hispanic             8      257                        30
# 96           Hispanic             9      381                        30
# 99           Hispanic            10      357                        30
# 102          Hispanic            11      292                        30
# 105          Hispanic            12      289                        30
#
#     status_type  count_y      rate
# 72       booked      142  0.489655
# 75       booked      156  0.509804
# 78       booked      205  0.512500
# 81       booked      177  0.522124
# 84       booked      225  0.547445
# 87       booked      136  0.548387
# 90       booked      116  0.617021
# 93       booked      149  0.579767
# 96       booked      189  0.496063
# 99       booked      185  0.518207
# 102      booked      153  0.523973
# 105      booked      140  0.484429

# %%
framejuvexplore6white = framejuvexplore6.loc[framejuvexplore6['race_or_ethnicity'] == 'White']
framejuvexplore6whitebooked = framejuvexplore6white.loc[framejuvexplore6white['status_type'] == 'booked']

# %%
framejuvexplore6whitebooked
# Out:
#     race_or_ethnicity  arrest_month  count_x  bcs_summary_offence_code  \
# 141             White             1      102                        30
# 144             White             2      125                        30
# 147             White             3      146                        30
# 150             White             4      129                        30
# 153             White             5      143                        30
# 156             White             6      111                        30
# 159             White             7       80                        30
# 162             White             8       91                        30
# 165             White             9      136                        30
# 168             White            10      146                        30
# 171             White            11      110                        30
# 174             White            12      105                        30
#
#     status_type  count_y      rate
# 141      booked       55  0.539216
# 144      booked       55  0.440000
# 147      booked       67  0.458904
# 150      booked       61  0.472868
# 153      booked       62  0.433566
# 156      booked       56  0.504505
# 159      booked       49  0.612500
# 162      booked       52  0.571429
# 165      booked       59  0.433824
# 168      booked       64  0.438356
# 171      booked       46  0.418182
# 174      booked       56  0.533333

# %% [markdown]
# ##Normality Test
# The Shapiro-Wilk normality test tests for differences between the observed distribution and normal distribution. If the p-value is greater than 5%, then the test does not reject the null hypothesis that the samples came from a normal distribution.

# %%
from scipy import stats
stats.shapiro(framejuvexplore6asianbooked.rate)
# Out:
# (0.9529476761817932, 0.6803945899009705)

# %%
stats.shapiro(framejuvexplore6blackbooked.rate)
# Out:
# (0.9557058811187744, 0.7212318181991577)

# %%
stats.shapiro(framejuvexplore6hispanicbooked.rate)
# Out:
# (0.9023861289024353, 0.170271635055542)

# %%
stats.shapiro(framejuvexplore6whitebooked.rate)
# Out:
# (0.8942013382911682, 0.13350442051887512)

# %% [markdown]
# ##Mean

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import math

# %%
np.mean(framejuvexplore6asianbooked.rate)
# Out:
# 0.34035310567568633

# %%
np.mean(framejuvexplore6blackbooked.rate)
# Out:
# 0.5387842921179384

# %%
np.mean(framejuvexplore6hispanicbooked.rate)
# Out:
# 0.5291145914266602

# %%
np.mean(framejuvexplore6whitebooked.rate)
# Out:
# 0.4880568639773168

# %% [markdown]
# ##Two-Sample T-Test
# In a two-sample test, the null hypothesis is that the means of both groups are the same. For our tests: If the p-value is smaller than 5%, then we reject the null hypothesis of equal averages.

# %%
stats.ttest_ind(a= framejuvexplore6asianbooked.rate,
                b= framejuvexplore6blackbooked.rate,
                equal_var=False)
# Out:
# Ttest_indResult(statistic=-5.3884798074962781, pvalue=6.6357601573991158e-05)

# %% [markdown]
# There is an extremely low chance (0.007%) we'd see sample data this far apart if the two groups tested are actually identical. There is a significant difference in booked rates between Asian and Black ethnicities.

# %%
stats.ttest_ind(a= framejuvexplore6hispanicbooked.rate,
                b= framejuvexplore6blackbooked.rate,
                equal_var=False)
# Out:
# Ttest_indResult(statistic=-0.50487665610907295, pvalue=0.61917171092199319)

# %% [markdown]
# There is a 61.92% chance we'd see sample data this far apart. There is no significant difference in booked rates between Black and Hispanic ethnicities.

# %%
stats.ttest_ind(a= framejuvexplore6whitebooked.rate,
                b= framejuvexplore6blackbooked.rate,
                equal_var=False)
# Out:
# Ttest_indResult(statistic=-2.114669104941119, pvalue=0.046322051250721807)

# %% [markdown]
# There is a 4.6% chance we'd see sample data this far apart. There is a significant difference in booked rates between White and Black ethnicities.

# %%
stats.ttest_ind(a= framejuvexplore6whitebooked.rate,
                b= framejuvexplore6asianbooked.rate,
                equal_var=False)
# Out:
# Ttest_indResult(statistic=3.8819257423387472, pvalue=0.0011927053701213388)

# %% [markdown]
# There is a 0.12% chance we'd see sample data this far apart. There is a significant difference in booked rates between White and Asian ethnicities.

# %% [markdown]
# ###For the same criminal offense of misdemeanor (offense code 30), black and hispanic ethnic juvenile groups are more likely to be booked (treated with harsher consequences by law enforcement) than white and asian juvenile groups.
